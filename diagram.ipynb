# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.pyplot import figure
import numpy as np

# %%
# ---------------- Evaluation metrics of each model  ----------------
models = ["Random Forest","LightGBM", "XGBoost", "CatBoost", "Gradient Boosting", "OT Catboost"]
rmse = [0.008345, 0.006719, 0.005951, 0.006366, 0.005646, 0.005561]
mse  = [0.000073, 0.000049, 0.000038, 0.000044, 0.000034, 0.000033]
mae  = [0.005027, 0.003430, 0.002563, 0.003029, 0.002770, 0.002312]
r2   = [0.600891, 0.744889, 0.796858, 0.771297, 0.818473, 0.821124]

# Tạo DataFrame
df = pd.DataFrame({
    "Model": models,
    "RMSE": rmse,
    "MSE": mse,
    "MAE": mae,
    "R²": r2
})

#highlight bol
def highlight_bold(s):
    if s.name in ["RMSE", "MSE", "MAE"]:
        is_min = s == s.min()
        return ['font-weight: bold' if v else '' for v in is_min]
    elif s.name == "R²":
        is_max = s == s.max()
        return ['font-weight: bold' if v else '' for v in is_max]
    return ['']*len(s)

styled_df = df.style.apply(highlight_bold)

styled_df
# Out:
# <style type="text/css">
# #T_f9759_row5_col1, #T_f9759_row5_col2, #T_f9759_row5_col3, #T_f9759_row5_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f9759">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9759_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f9759_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_f9759_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f9759_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_f9759_level0_col4" class="col_heading level0 col4" >R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9759_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9759_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_f9759_row0_col1" class="data row0 col1" >0.008345</td>
#       <td id="T_f9759_row0_col2" class="data row0 col2" >0.000073</td>
#       <td id="T_f9759_row0_col3" class="data row0 col3" >0.005027</td>
#       <td id="T_f9759_row0_col4" class="data row0 col4" >0.600891</td>
#     </tr>
#     <tr>
#       <th id="T_f9759_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9759_row1_col0" class="data row1 col0" >LightGBM</td>
#       <td id="T_f9759_row1_col1" class="data row1 col1" >0.006719</td>
#       <td id="T_f9759_row1_col2" class="data row1 col2" >0.000049</td>
#       <td id="T_f9759_row1_col3" class="data row1 col3" >0.003430</td>
#       <td id="T_f9759_row1_col4" class="data row1 col4" >0.744889</td>
#     </tr>
#     <tr>
#       <th id="T_f9759_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9759_row2_col0" class="data row2 col0" >XGBoost</td>
#       <td id="T_f9759_row2_col1" class="data row2 col1" >0.005951</td>
#       <td id="T_f9759_row2_col2" class="data row2 col2" >0.000038</td>
#       <td id="T_f9759_row2_col3" class="data row2 col3" >0.002563</td>
#       <td id="T_f9759_row2_col4" class="data row2 col4" >0.796858</td>
#     </tr>
#     <tr>
#       <th id="T_f9759_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9759_row3_col0" class="data row3 col0" >CatBoost</td>
#       <td id="T_f9759_row3_col1" class="data row3 col1" >0.006366</td>
#       <td id="T_f9759_row3_col2" class="data row3 col2" >0.000044</td>
#       <td id="T_f9759_row3_col3" class="data row3 col3" >0.003029</td>
#       <td id="T_f9759_row3_col4" class="data row3 col4" >0.771297</td>
#     </tr>
#     <tr>
#       <th id="T_f9759_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9759_row4_col0" class="data row4 col0" >Gradient Boosting</td>
#       <td id="T_f9759_row4_col1" class="data row4 col1" >0.005646</td>
#       <td id="T_f9759_row4_col2" class="data row4 col2" >0.000034</td>
#       <td id="T_f9759_row4_col3" class="data row4 col3" >0.002770</td>
#       <td id="T_f9759_row4_col4" class="data row4 col4" >0.818473</td>
#     </tr>
#     <tr>
#       <th id="T_f9759_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9759_row5_col0" class="data row5 col0" >OT Catboost</td>
#       <td id="T_f9759_row5_col1" class="data row5 col1" >0.005561</td>
#       <td id="T_f9759_row5_col2" class="data row5 col2" >0.000033</td>
#       <td id="T_f9759_row5_col3" class="data row5 col3" >0.002312</td>
#       <td id="T_f9759_row5_col4" class="data row5 col4" >0.821124</td>
#     </tr>
#   </tbody>
# </table>

# %%
#experiment 20 times
# ---------------- Evaluation metrics of each model  ----------------
models = ["Random Forest","LightGBM", "XGBoost", "CatBoost", "Gradient Boosting", "OT Catboost"]
rmse = [8.38109364e-03, 6.72770217e-03, 5.90261607e-03, 6.38628133e-03, 5.64593443e-03, 5.51436551e-03]
mse  = [7.33904851e-05, 4.81008961e-05, 0.72631871e-05, 4.36972632e-05, 3.42586914e-05, 3.25184076e-05]
mae  = [5.02930617e-03, 3.43355142e-03, 2.55673572e-03, 3.03607004e-03, 2.76763597e-03, 2.31153468e-03 ]
r2   = [5.96232204e-01, 7.41697864e-01, 8.00197304e-01, 7.67375969e-01, 8.18608814e-01, 8.23362410e-01]

# Tạo DataFrame
df = pd.DataFrame({
    "Model": models,
    "RMSE": rmse,
    "MSE": mse,
    "MAE": mae,
    "R²": r2
})

#highlight bol
def highlight_bold(s):
    if s.name in ["RMSE", "MSE", "MAE"]:
        is_min = s == s.min()
        return ['font-weight: bold' if v else '' for v in is_min]
    elif s.name == "R²":
        is_max = s == s.max()
        return ['font-weight: bold' if v else '' for v in is_max]
    return ['']*len(s)

styled_df = df.style.apply(highlight_bold)

styled_df

# %%
#BOX PLOT FOR MEAN OF EACH METRIC
xgbo = np.array([[6.11789608e-03, 4.06582343e-05, 2.56373211e-03, 7.86757923e-01],
       [5.88863124e-03, 3.74558124e-05, 2.55512428e-03, 8.02482121e-01],
       [5.92400186e-03, 3.68940336e-05, 2.55256354e-03, 7.98115596e-01],
       [5.89557368e-03, 3.64830889e-05, 2.55727595e-03, 7.99412479e-01],
       [5.92631658e-03, 3.75172084e-05, 2.55764964e-03, 7.99805341e-01],
       [5.91111282e-03, 3.80614049e-05, 2.55817868e-03, 8.00373843e-01],
       [5.86726996e-03, 3.70165200e-05, 2.55616933e-03, 8.02231135e-01],
       [5.91635367e-03, 3.73707455e-05, 2.55911517e-03, 7.97660193e-01],
       [5.84656402e-03, 3.59101852e-05, 2.55682002e-03, 8.03515100e-01],
       [5.80888648e-03, 3.61341777e-05, 2.55217503e-03, 8.07345152e-01],
       [5.87366877e-03, 3.69938398e-05, 2.55543562e-03, 8.03038986e-01],
       [5.77542418e-03, 3.71568345e-05, 2.55466388e-03, 8.12234040e-01],
       [5.89270328e-03, 3.67195330e-05, 2.55587298e-03, 8.01010009e-01],
       [5.90221148e-03, 3.66601941e-05, 2.55543144e-03, 7.97509900e-01],
names = ['RMSE', 'MSE' ,'MAE', 'R2']

figure(num=None, figsize=(10, 5))
y_pos=np.arange(len(names))
plt.bar(y_pos + 0, xgboost,width=0.1, color = '#FFB3BA' , label='XGBoost')
plt.bar(y_pos + 0.1, cat1,width=0.1, color = '#A7C7E7' , label='CatBoost')
plt.bar(y_pos + 0.2, cat2,width=0.1, color = '#FFD1A9' , label='OT-Catboost')
plt.bar(y_pos + 0.3, lgb,width=0.1, color = '#B6E3B6' , label='LightGBM')
plt.bar(y_pos + 0.4, rd,width=0.1, color = '#C8A2C8', label='RandomForest')
plt.bar(y_pos + 0.5, rd,width=0.1, color = '#FFF4A3', label='Gradient Boosting')
font = {
#     'family' : 'Times New Roman',
#         'weight' : 'bold',
        'size'   : 18}
plt.rcParams.update({'font.size': 18})
plt.rc('font', **font)
plt.ylim(0.001, 1)
plt.xticks(y_pos, names)
plt.legend(('XGBoost','CatBoost','OT-Catboost', 'LightGBM', 'Random Forest','Gradient Boosting'),loc='upper left')
plt.savefig('mathG3C.eps', format='eps',bbox_inches='tight')
# plt.title("Put a title here")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#rmse
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 0
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="RMSE")

plt.show()

# %%
#mse
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 1
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="MSE")

plt.show()

# %%
#mae
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 2
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="MAE")

plt.show()

# %%
#r2
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 3
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="R2")

plt.show()
