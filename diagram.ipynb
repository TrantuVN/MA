# %%
import seaborn as sns
import pandas as pd
from matplotlib.pyplot import figure
import numpy as np

# %%
# ---------------- Evaluation metrics of each model  ----------------
models = ["Random Forest","LightGBM", "XGBoost", "CatBoost", "Gradient Boosting", "OT Catboost"]
rmse = [0.008349, 0.006719, 0.005951, 0.006366, 0.005646, 0.005454]
mse  = [0.000073, 0.000049, 0.000038, 0.000044, 0.000034, 0.000032]
mae  = [0.005028, 0.003430, 0.002563, 0.003029, 0.002770, 0.002240]
r2   = [0.600404, 0.744889, 0.796858, 0.771297, 0.818473, 0.828335]

# Tạo DataFrame
df = pd.DataFrame({
    "Model": models,
    "RMSE": rmse,
    "MSE": mse,
    "MAE": mae,
    "R²": r2
})

#highlight bol
def highlight_bold(s):
    if s.name in ["RMSE", "MSE", "MAE"]:
        is_min = s == s.min()
        return ['font-weight: bold' if v else '' for v in is_min]
    elif s.name == "R²":
        is_max = s == s.max()
        return ['font-weight: bold' if v else '' for v in is_max]
    return ['']*len(s)

styled_df = df.style.apply(highlight_bold)

styled_df
# Out:
# <style type="text/css">
# #T_73a5b_row5_col1, #T_73a5b_row5_col2, #T_73a5b_row5_col3, #T_73a5b_row5_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_73a5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73a5b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_73a5b_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_73a5b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_73a5b_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_73a5b_level0_col4" class="col_heading level0 col4" >R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73a5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73a5b_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_73a5b_row0_col1" class="data row0 col1" >0.008349</td>
#       <td id="T_73a5b_row0_col2" class="data row0 col2" >0.000073</td>
# ...

# %%
#experiment 20 times
# ---------------- Evaluation metrics of each model  ----------------
models = ["Random Forest","LightGBM", "XGBoost", "CatBoost", "Gradient Boosting", "OT Catboost"]
rmse = [8.38728320e-03, 6.72770217e-03, 5.90261607e-03, 6.38628133e-03, 5.64593443e-03, 5.48998777e-03]
mse  = [7.34824746e-05, 4.81008961e-05, 3.72631871e-05, 4.36972632e-05, 3.42586914e-05, 3.24958257e-05]
mae  = [5.03021479e-03, 3.43355142e-03, 2.55673572e-03, 3.03607004e-03, 2.76763597e-03, 2.26713175e-03]
r2   = [5.95596111e-01, 7.41697864e-01, 8.00197304e-01, 7.67375969e-01, 8.18608814e-01, 8.25827107e-01]

# Tạo DataFrame
df = pd.DataFrame({
    "Model": models,
    "RMSE": rmse,
    "MSE": mse,
    "MAE": mae,
    "R²": r2
})

#highlight bol
def highlight_bold(s):
    if s.name in ["RMSE", "MSE", "MAE"]:
        is_min = s == s.min()
        return ['font-weight: bold' if v else '' for v in is_min]
    elif s.name == "R²":
        is_max = s == s.max()
        return ['font-weight: bold' if v else '' for v in is_max]
    return ['']*len(s)

styled_df = df.style.apply(highlight_bold)

styled_df
# Out:
# <style type="text/css">
# #T_8ed45_row5_col1, #T_8ed45_row5_col2, #T_8ed45_row5_col3, #T_8ed45_row5_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8ed45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ed45_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8ed45_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_8ed45_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8ed45_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_8ed45_level0_col4" class="col_heading level0 col4" >R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ed45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ed45_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T
       [5.47142653e-03, 3.27816046e-05, 2.27027689e-03, 8.29340602e-01],
       [5.51990472e-03, 3.42359357e-05, 2.26424613e-03, 8.25839589e-01],
       [5.37269198e-03, 3.04633400e-05, 2.26164040e-03, 8.30767461e-01],
       [5.41119950e-03, 3.08865905e-05, 2.26459151e-03, 8.27731252e-01],
       [5.50957351e-03, 3.18427564e-05, 2.26427646e-03, 8.22900265e-01],
       [5.46210693e-03, 3.26661016e-05, 2.26600216e-03, 8.28627093e-01],
       [5.49669556e-03, 3.35403170e-05, 2.26210183e-03, 8.26677569e-01],
       [5.41723100e-03, 3.12800156e-05, 2.26502405e-03, 8.28706683e-01],
       [5.44279221e-03, 3.20179538e-05, 2.26104312e-03, 8.28849537e-01],
       [5.36886529e-03, 3.05879190e-05, 2.26345460e-03, 8.31055543e-01]])

# %%
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt

xgboost = np.mean(xgbo, axis=0)
gd = np.mean(gra, axis=0)
cat1 = np.mean(cat, axis=0)
cat2 = np.mean(procat, axis=0)
lgb = np.mean(lgbm, axis=0)
rd = np.mean(random, axis=0)

names = ['RMSE', 'MSE' ,'MAE', 'R2']

figure(num=None, figsize=(10, 5))
y_pos=np.arange(len(names))
plt.bar(y_pos + 0, xgboost,width=0.1, color = '#FFB3BA' , label='XGBoost')
plt.bar(y_pos + 0.1, cat1,width=0.1, color = '#A7C7E7' , label='CatBoost')
plt.bar(y_pos + 0.2, cat2,width=0.1, color = '#FFD1A9' , label='OT-Catboost')
plt.bar(y_pos + 0.3, lgb,width=0.1, color = '#B6E3B6' , label='LightGBM')
plt.bar(y_pos + 0.4, rd,width=0.1, color = '#C8A2C8', label='RandomForest')
plt.bar(y_pos + 0.5, rd,width=0.1, color = '#FFF4A3', label='Gradient Boosting')
font = {
#     'family' : 'Times New Roman',
#         'weight' : 'bold',
        'size'   : 18}
plt.rcParams.update({'font.size': 18})
plt.rc('font', **font)
plt.ylim(0.001, 1)
plt.xticks(y_pos, names)
plt.legend(('XGBoost','CatBoost','OT-Catboost', 'LightGBM', 'Random Forest','Gradient Boosting'),loc='upper left')
plt.savefig('mathG3C.eps', format='eps',bbox_inches='tight')
# plt.title("Put a title here")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#rmse
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 0
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="RMSE")

plt.show()

# %%
#mse
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 1
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="MSE")

plt.show()

# %%
#mae
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 2
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="MAE")

plt.show()

# %%
#r2
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 3
df["XGBoost"] = xgbo[:, i]
df["CatBoost"] = cat[:, i]
df["LightGBM"] = lgbm[:, i]
df["Random Forest"]      = random[:, i]
df["Gradient Boosting"]  = gra[:, i] 
df['OT-Catboost'] = procat[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="R2")

plt.show()

# %%
#entrypoint v06, 20 times, wilcoxon test 
from scipy.stats import ranksums

models = {
    "OT-CatBoost": procat,   # reference
    "CatBoost":     cat,
    "RandomForest": random,
    "LightGBM":     lgbm,
    "XGBoost":      gra,
    "GBR":          xgbo
}
for i in range(4):
    print(ranksums(procat[:,i], cat[:,i]).pvalue)
    print(ranksums(procat[:,i], random[:,i]).pvalue)
    print(ranksums(procat[:,i], lgbm[:,i]).pvalue)
    print(ranksums(procat[:,i], gra[:,i]).pvalue)
    print(ranksums(procat[:,i], xgbo[:,i]).pvalue)
    print()
# Out:
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
#
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
# 2.2039225490118196e-06
# 6.301848221392269e-08
#
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
#
# 6.301848221392269e-08
# 6.301848221392269e-08
# 6.301848221392269e-08
# 9.882703709104184e-08
# 6.301848221392269e-08

# %%
#entrypoint address v07
import numpy as np
import pandas as pd
# ---------------- Evaluation metrics of each model  ----------------
models = ["Random Forest","LightGBM", "XGBoost", "CatBoost", "Gradient Boosting", "OT Catboost"]
rmse = [0.006805, 0.006115, 0.005700, 0.004934, 0.005587, 0.004396]
mse  = [0.000060, 0.000053, 0.000054, 0.000032, 0.000042, 0.000035]
mae  = [0.002242, 0.001505, 0.001305, 0.002005, 0.001834, 0.001107]
r2   = [0.558993, 0.567950, 0.563501, 0.765230, 0.707424, 0.804192]

# Tạo DataFrame
df = pd.DataFrame({
    "Model": models,
    "RMSE": rmse,
    "MSE": mse,
    "MAE": mae,
    "R²": r2
})

#highlight bol
def highlight_bold(s):
    if s.name in ["RMSE", "MSE", "MAE"]:
        is_min = s == s.min()
        return ['font-weight: bold' if v else '' for v in is_min]
    elif s.name == "R²":
        is_max = s == s.max()
        return ['font-weight: bold' if v else '' for v in is_max]
    return ['']*len(s)

styled_df = df.style.apply(highlight_bold)
styled_df
# Out:
# <style type="text/css">
# #T_97ab7_row3_col2, #T_97ab7_row5_col1, #T_97ab7_row5_col3, #T_97ab7_row5_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_97ab7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97ab7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_97ab7_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_97ab7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_97ab7_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_97ab7_level0_col4" class="col_heading level0 col4" >R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97ab7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97ab7_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_97ab7_row0_col1" class="data row0 col1" >0.006805</td>
#       <td id="T_97ab7_row0_col2" class="data row0 col2" >0.000060</td>
# ...

# %%
#entrypoint v07, run 20 times, each model

cat1 = np.array([[4.61965743e-03, 2.76013290e-05, 1.88945755e-03, 7.98820894e-01],
       [4.84342279e-03, 3.11622951e-05, 1.95634721e-03, 7.75836688e-01],
       [4.58011719e-03, 2.49952171e-05, 1.94192881e-03, 7.99186756e-01],
       [4.43368401e-03, 3.51791885e-05, 1.10998325e-03, 8.00195870e-01],
       [4.44713686e-03, 3.49664632e-05, 1.10967070e-03, 7.99450197e-01],
       [4.47624991e-03, 3.56741440e-05, 1.11146391e-03, 7.95950422e-01],
       [4.42348779e-03, 3.47651402e-05, 1.11010053e-03, 8.01306983e-01],
       [4.47779451e-03, 3.47182522e-05, 1.11402110e-03, 7.97700075e-01],
       [4.43827686e-03, 3.54743370e-05, 1.11229435e-03, 7.99917089e-01]])

# %%
#rmse, entrypoint v7, run 20 times
import seaborn as sns
import matplotlib.pyplot as plt 
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 0
df["XGBoost"] = xg1[:, i]
df["CatBoost"] = cat1[:, i]
df["LightGBM"] = light1[:, i]
df["Random Forest"] = ran1[:, i]
df["Gradient Boosting"]  = grad1[:, i] 
df['OT-Catboost'] = procat1[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="RMSE")

plt.show()

# %%
#mse, entrypoint v7, run 20 times
import seaborn as sns
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 1
df["XGBoost"] = xg1[:, i]
df["CatBoost"] = cat1[:, i]
df["LightGBM"] = light1[:, i]
df["Random Forest"] = ran1[:, i]
df["Gradient Boosting"]  = grad1[:, i] 
df['OT-Catboost'] = procat1[:, i]
fig, ax = plt.subplots(figsize=(7.5, 4))
sns.boxplot(data=df, orient='h', showfliers=True, ax=ax)  # có outlier
ax.set_xscale('log')
ax.set_xlabel("MSE (log scale)")
ax.set_ylabel("")
plt.tight_layout()
plt.show()

# %%
#mae, entrypoint v7, run 20 times
import seaborn as sns
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 2
df["XGBoost"] = xg1[:, i]
df["CatBoost"] = cat1[:, i]
df["LightGBM"] = light1[:, i]
df["Random Forest"] = ran1[:, i]
df["Gradient Boosting"]  = grad1[:, i] 
df['OT-Catboost'] = procat1[:, i]
fig, ax = plt.subplots(figsize=(8, 5))
sns.boxplot(data=df, orient='h', showfliers=True, ax=ax)  # có outlier
ax.set_xscale('log')
ax.set_xlabel("MAE (log scale)")
ax.set_ylabel("")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
df = pd.DataFrame(columns=['XGBoost','CatBoost','LightGBM','Random Forest','Gradient Boosting','OT-Catboost'])
i = 3
df["XGBoost"] = xg1[:, i]
df["CatBoost"] = cat1[:, i]
df["LightGBM"] = light1[:, i]
df["Random Forest"] = ran1[:, i]
df["Gradient Boosting"]  = grad1[:, i] 
df['OT-Catboost'] = procat1[:, i]
ax = sns.boxplot(data=df,orient='h')#, x=x, y=y, hue=hue
ax.set(xlabel="R_squared")
plt.show()

# %%
#wilcoxon, entrypoint v07, run 20 times
from scipy.stats import ranksums
for i in range(4):
    print(ranksums(procat1[:,i], cat1[:,i]).pvalue)
    print(ranksums(procat1[:,i], ran1[:,i]).pvalue)
    print(ranksums(procat1[:,i], light1[:,i]).pvalue)
    print(ranksums(procat1[:,i], grad1[:,i]).pvalue)
    print(ranksums(procat1[:,i], xg1[:,i]).pvalue)
    print()
# Out:
# 0.05146207608338068
# 0.0200021438173071
# 0.0200021438173071
# 0.0200021438173071
# 0.0200021438173071
#
# 0.0001892785216405046
# 0.0200021438173071
# 0.3437645971341301
# 0.0200021438173071
# 0.0200021438173071
#
# 0.0200021438173071
# 1.1753304953705375e-05
# 0.0200021438173071
# 0.0200021438173071
# 0.0200021438173071
#
# 0.00013670084197896473
# 6.301848221392269e-08
# 5.50880416974011e-06
# 6.301848221392269e-08
# 4.87123053504645e-07

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats
[4.43319886e-03, 3.45965322e-05, 1.11485695e-03, 8.01728919e-01], [4.44561474e-03, 3.49250274e-05, 1.12106860e-03, 8.00139828e-01], [4.43152384e-03, 3.51038805e-05, 1.11238909e-03, 8.00811498e-01], [4.45756902e-03, 3.50201267e-05, 1.11835206e-03, 7.98102564e-01], [4.40115635e-03, 3.52164670e-05, 1.11285419e-03, 8.02673719e-01], [4.39973881e-03, 3.44768369e-05, 1.11043382e-03, 8.03247122e-01], [4.46630245e-03, 3.56421273e-05, 1.11538367e-03, 7.98424488e-01], [4.44700367e-03, 3.48456666e-05, 1.11094798e-03, 7.98876858e-01], [4.44500891e-03, 3.51381098e-05, 1.11893297e-03, 7.99885235e-01], [1.80301278e-02, 2.51374514e-03, 2.25564234e-03, 8.45385504e-01], [4.46313453e-03, 3.50883745e-05, 1.11821707e-03, 7.99260542e-01], [4.41463020e-03, 3.48281385e-05, 1.11744057e-03, 8.02691865e-01], [4.36369814e-03, 3.42412245e-05, 1.11230286e-03, 8.06201571e-01]])

# =============================================================================
# ANALYSIS LOGIC
# =============================================================================

METRICS = ["RMSE", "MSE", "MAE", "R2"]
HIGHER_IS_BETTER = {"R2"}

def to_loss(v: np.ndarray, metric: str) -> np.ndarray:
    """Convert to loss so smaller is always better for ranking."""
    return -v if metric in HIGHER_IS_BETTER else v

def p_str(p):
    """Formats p-value for display."""
    if p == 0:
        return "p < 1e-300"
    if p < 1e-3:
        return f"p = {p:.1e}"
    return f"p = {p:.3f}"

def run_friedman(entry_title: str, model_arrays: dict):
    """Runs Friedman test and returns a dictionary with results for plotting."""
    print(f"\n================ {entry_title} (Friedman only) ================\n")
    model_names = list(model_arrays.keys())
    n = next(iter(model_arrays.values())).shape[0]

    out = {"meta": {"title": entry_title}, "friedman": {}}

    for m_idx, metric in enumerate(METRICS):
        # Build loss-mapped table for ranking
        data_loss = {
            name: to_loss(model_arrays[name][:, m_idx].astype(float), metric)
            for name in model_names
        }
        df_loss = pd.DataFrame(data_loss)

        # Friedman test
        samples = [df_loss[col].values for col in df_loss.columns]
        chi2, p = friedmanchisquare(*samples)
        df = len(model_names) - 1
        out["friedman"][metric] = {"chi2": float(chi2), "df": df, "p": float(p)}

        # Calculate ranks and original means
        ranks = df_loss.rank(axis=1, method="average", ascending=True)
        avg_ranks = ranks.mean()
        means_orig = {name: float(np.mean(model_arrays[name][:, m_idx])) for name in model_names}

        summary = (
            pd.DataFrame({
                "Model": model_names,
                "Mean": [means_orig[nm] for nm in model_names],
                "AvgRank": [avg_ranks[nm] for nm in model_names],
            })
            .sort_values("AvgRank")
            .reset_index(drop=True)
        )
        out[metric] = summary

        # Print summary
        print(f"--- {metric} ---")
        print(f"Friedman χ²({df}) = {chi2:.4f}, {p_str(p)}")
        print(summary.round(6).to_string(index=False))
        print("-" * 70)
    return out

def plot_entrypoint_ranks(results_dict, metrics=("RMSE", "MSE", "MAE", "R2")):
    """
    Creates a single figure with a 1x4 panel of lollipop plots for one EntryPoint version.
    """
    title = results_dict["meta"]["title"]
    fig, axes = plt.subplots(1, len(metrics), figsize=(14, 5), constrained_layout=True)
    
    # Use a consistent color palette
    colors = plt.cm.viridis(np.linspace(0, 1, 6))

    for col, metric in enumerate(metrics):
        ax = axes[col]
        df = results_dict[metric].copy().sort_values("AvgRank")
        y = np.arange(len(df))
        
        # Create a color map based on rank
        rank_colors = [colors[int(rank-1)] for rank in df['AvgRank'].rank(method='dense')-1]

        ax.hlines(y, xmin=1, xmax=df["AvgRank"], color='gray', alpha=0.5)
        ax.plot(df["AvgRank"], y, "o", ms=8, c='black') # Markers
        # Add colored markers on top
        for i, rank_val in enumerate(df["AvgRank"]):
             ax.plot(rank_val, y[i], "o", ms=7, color=rank_colors[i])


        # Y-axis labels only on the first plot
        if col == 0:
            ax.set_yticks(y)
            ax.set_yticklabels(df["Model"], fontdict={'fontsize': 10})
        else:
            ax.set_yticks([])

        ax.invert_yaxis()
        ax.set_xlim(0.8, max(6.2, df["AvgRank"].max() + 0.2))
        ax.set_xlabel("Average Rank (lower is better)", fontsize=10)

        # Add metric title and Friedman stats
        fr = results_dict["friedman"][metric]
        ax.set_title(f"{metric}\nχ²({fr['df']})={fr['chi2']:.2f}, {p_str(fr['p'])}",
                      loc="left", fontsize=10)
        ax.grid(axis="x", alpha=0.4, linestyle="--")

    fig.suptitle(f"Model Performance Ranks for {title}", fontsize=14, fontweight="bold")
    plt.savefig(f"lollipop_rank_plot_{title.replace(' ', '_')}.png", dpi=300, bbox_inches='tight')
    plt.show()

# =============================================================================
# PACK & RUN
# =============================================================================
v06_data = {
    "OT-CatBoost": procat_v06,
    "CatBoost":     cat_v06,
    "RandomForest": random_v06,
    "LightGBM":     lgbm_v06,
    "GradBoost":    gra_v06,
    "XGBoost":      xgbo_v06,
}

v07_data = {
    "OT-CatBoost": procat_v07,
    "CatBoost":     cat_v07,
    "RandomForest": ran_v07,
    "LightGBM":     light_v07,
    "GradBoost":    grad_v07,
    "XGBoost":      xg_v07,
}

# Run analysis and get dictionaries for plotting
v06_results = run_friedman("ENTRYPOINT v06", v06_data)
v07_results = run_friedman("ENTRYPOINT v07", v07_data)

# Create two separate plots
plot_entrypoint_ranks(v06_results)
plot_entrypoint_ranks(v07_results)
# Out:
# ================ ENTRYPOINT v06 (Friedman only) ================
#
# --- RMSE ---
# Friedman χ²(5) = 100.0000, p = 5.3e-20
#        Model     Mean  AvgRank
#  OT-CatBoost 0.005514      1.0
#    GradBoost 0.005646      2.0
#      XGBoost 0.005903      3.0
#     CatBoost 0.006386      4.0
#     LightGBM 0.006728      5.0
# RandomForest 0.008381      6.0
# ----------------------------------------------------------------------
# --- MSE ---
# Friedman χ²(5) = 98.8857, p = 9.1e-20
#        Model     Mean  AvgRank
#  OT-CatBoost 0.000033     1.05
#    GradBoost 0.000034     2.00
#      XGBoost 0.000037     2.95
#     CatBoost 0.000044     4.00
#     LightGBM 0.000048     5.00
# RandomForest 0.000073     6.00
# ----------------------------------------------------------------------
# --- MAE ---
# Friedman χ²(5) = 100.0000, p = 5.3e-20
#        Model     Mean  AvgRank
#  OT-CatBoost 0.002312      1.0
#      XGBoost 0.002557      2.0
#    GradBoost 0.002768      3.0
# ...
